# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.arange(-100.0, 100.0, 0.01)
a1 = 3
a2 = 4
e = a1 * t + a2 * t ** 2

# %%
rm = 3 #Rш
rd = 2  #Rд
r = 3
i = (rm)/(rd*rm + rd*r  +rm*r) * t

# %%
b = 50
f = 3
w = 2
m = b*w*f*i

# %%
ee = 1
b = 2
h = 4
l = 3
csh = b*h**3*ee/12/l
phi = m/2/csh

# %%
fig, ax = plt.subplots(figsize=(6, 6))
ax.plot (t,e)
ax.grid()

# %%
fig, ay = plt.subplots(figsize=(6, 6))
ay.set_xlim(-100, 100)
ay.set_ylim(-100,100)
ay.plot (t,i)
ay.grid()

# %%
fig1,az = plt.subplots(figsize=(6, 6))
az.set_xlim(-100, 100)
az.set_ylim(-100,100)
az.locator_params(nbins = 10)
az.plot(t,m)
az.grid()

# %%
fig1,ar = plt.subplots(figsize=(6, 6))
ar.set_xlim(-100, 100)
ar.set_ylim(-100,100)
ar.locator_params(nbins = 10)
ar.plot(t,phi)
ar.grid()
